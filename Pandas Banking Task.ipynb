# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Athar\Desktop\Bank Dataset\bank.csv",sep=";")

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# # 1.How many campaigns available in this datasets

# %%
df.campaign.unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
df.campaign.value_counts()
# Out:
# 1     1734
# 2     1264
# 3      558
# 4      325
# 5      167
# 6      155
# 7       75
# 8       56
# 9       30
# 10      27
# 11      22
# 12      21
# 13      17
# 14      10
# 15       9
# 16       8
# 17       7
# 18       7
# 25       4
# 19       3
# 20       3
# 24       3
# 28       3
# 23       2
# 22       2
# 21       2
# 32       2
# 29       1
# 50       1
# 30       1
# 44       1
# 31       1
# Name: campaign, dtype: int64

# %% [markdown]
# # 2. How many users do we have with housing and personal loans

# %%
(df["housing"]=="yes").value_counts()
# Out:
# True     2559
# False    1962
# Name: housing, dtype: int64

# %%
(c=="yes").value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-dc8fd202d986> in <module>
# ----> 1 (c=="yes").value_counts()
#
# NameError: name 'c' is not defined

# %% [markdown]
# # 3.How many persons do we have have whose age is above 60+

# %%
(df["age"]>60).value_counts()
# Out:
# False    4394
# True      127
# Name: age, dtype: int64

# %% [markdown]
# # 4. In which months we have targeted most of the customers

# %%
df2=df[df["y"]=="yes"]

# %%
df2.head()
# Out:
#     age         job   marital  education default  balance housing loan  \
# 13   20     student    single  secondary      no      502      no   no
# 30   68     retired  divorced  secondary      no     4189      no   no
# 33   32  management    single   tertiary      no     2536     yes   no
# 34   49  technician   married   tertiary      no     1235      no   no
# 36   78     retired  divorced    primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 13   cellular   30   apr       261         1     -1         0  unknown  yes
# 30  telephone   14   jul       897         2     -1         0  unknown  yes
# 33   cellular   26   aug       958         6     -1         0  unknown  yes
# 34   cellular   13   aug       354         3     -1         0  unknown  yes
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
df2.groupby('month',axis=0).count()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# month
# apr     56   56       56         56       56       56       56    56       56
# aug     79   79       79         79       79       79       79    79       79
# dec      9    9        9          9        9        9        9     9        9
# feb     38   38       38         38       38       38       38    38       38
# jan     16   16       16         16       16       16       16    16       16
# jul     61   61       61         61       61       61       61    61       61
# jun     55   55       55         55       55       55       55    55       55
# mar     21   21       21         21       21       21       21    21       21
# may     93   93       93         93       93       93       93    93       93
# nov     39   39       39         39       39       39       39    39       39
# oct     37   37       37         37       37       37       37    37       37
# ...

# %% [markdown]
# # 5. Which mode of call is giving you more result

# %%
df3=df[df["y"]=="yes"]

# %%
df3.groupby("contact").count()
# Out:
#            age  job  marital  education  default  balance  housing  loan  day  \
# contact
# cellular   416  416      416        416      416      416      416   416  416
# telephone   44   44       44         44       44       44       44    44   44
# unknown     61   61       61         61       61       61       61    61   61
#
#            month  duration  campaign  pdays  previous  poutcome    y
# contact
# cellular     416       416       416    416       416       416  416
# telephone     44        44        44     44        44        44   44
# unknown       61        61        61     61        61        61   61

# %% [markdown]
# # 6. How many entrepreneurs do we have in the list??

# %%
(df["job"]=="entrepreneur").value_counts()
# Out:
# False    4353
# True      168
# Name: job, dtype: int64

# %% [markdown]
# # 7. How many Customers do we have with negative balance.

# %%
(df["balance"]<0).value_counts()
# Out:
# False    4155
# True      366
# Name: balance, dtype: int64

# %% [markdown]
# # 8. Prepare a group of data based on education level

# %%
df.groupby("education").count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187
